# %%
import numpy as np
import apogee.tools.read as apread
import csv

# %%
from apogee.tools import bitmask
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-ac8c30867942> in <module>()
# ----> 1 from apogee.tools import bitmask
#
# /Users/reynaa/anaconda/lib/python3.6/site-packages/apogee-1.-py3.6.egg/apogee/tools/bitmask.py in <module>()
#      64                 13:"SIG_TELLURIC",
#      65                 14:"NOT_ENOUGH_PSF"}
# ---> 66 APOGEE_TARGET1_STR= dict((value, key) for key, value in APOGEE_TARGET1.iteritems())
#      67 APOGEE_TARGET2_STR= dict((value, key) for key, value in APOGEE_TARGET2.iteritems())
#      68 APOGEE_PIXMASK_STR= dict((value, key) for key, value in APOGEE_PIXMASK.iteritems())
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %%
from apogee.tools import bitmask
bitmask.apogee_target1_int('APOGEE_MDWARF')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-4bdaa73cf4c6> in <module>()
# ----> 1 from apogee.tools import bitmask
#       2 bitmask.apogee_target1_int('APOGEE_MDWARF')
#
# /Users/reynaa/anaconda/lib/python3.6/site-packages/apogee-1.-py3.6.egg/apogee/tools/bitmask.py in <module>()
#      64                 13:"SIG_TELLURIC",
#      65                 14:"NOT_ENOUGH_PSF"}
# ---> 66 APOGEE_TARGET1_STR= dict((value, key) for key, value in APOGEE_TARGET1.iteritems())
#      67 APOGEE_TARGET2_STR= dict((value, key) for key, value in APOGEE_TARGET2.iteritems())
#      68 APOGEE_PIXMASK_STR= dict((value, key) for key, value in APOGEE_PIXMASK.iteritems())
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %%
from astropy.io import fits
hdulist = fits.open('/Volumes/coveydata-1/APOGEE_Spectra/APOGEE2_DR13/5011/apStar-r6-2M19150038+4423231.fits')

# %%
hdulist.info()
# Out:
# Filename: /Volumes/coveydata-1/APOGEE_Spectra/APOGEE2_DR13/5011/apStar-r6-2M19150038+4423231.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     107   ()
#   1              ImageHDU        12   (8575,)   float32
#   2              ImageHDU        12   (8575,)   float32
#   3              ImageHDU        12   (8575,)   int16
#   4              ImageHDU        12   (8575,)   float32
#   5              ImageHDU        12   (8575,)   float32
#   6              ImageHDU        12   (8575,)   float32
#   7              ImageHDU        12   (8575,)   float32
#   8              ImageHDU        29   (26,)   float64
#   9              BinTableHDU     75   1R x 29C   [30A, I, 4A, J, I, D, E, E, E, E, 2I, 2E, 2E, 2E, 2E, E, E, E, E, E, E, E, E, 401E, 401E, 401E, D, D, 401E]

# %%
hdulist[0].header
# TARGET 1 -> Bit 19 = M-dwarfs
# Out:
# SIMPLE  =                    T /image conforms to FITS standard
# BITPIX  =                   16 /bits per data value
# NAXIS   =                    0 /number of axes
# EXTEND  =                    T /file may contain extensions
# DATE    = '2016-01-26'         / Creation UTC (CCCC-MM-DD) date of FITS header
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode 2001A&A...376..359H
# OBJID   = '2M19150038+4423231' / Object ID
# J       =              10.6500 / 2MASS J magnitude
# H       =              9.78200 / 2MASS H magnitude
# K       =              9.59300 / 2MASS Ks magnitude
# TARG1   =           -939524096 / First APOGEE targeting flag (bitwise, see docs)
# TARG2   =                    0 / Second APOGEE targeting flag (bitwise, see docs
# TARG3   =                    0 / Third APOGEE targeting flag (bitwise, see docs)
# SURVEY  = 'apogee  '           / Survey name (for targeting flags)
# ...

# %%
hdulist[0].header[11]
# Out:
# -939524096

# %%
hdulist[0].header[12]
# Out:
# 0

# %%
hdulist[0].header[13]
# Out:
# 0

# %%
hdu = hdulist[0].header
hdu['TARG1']
# Out:
# -939524096

# %%
data = fits.open('/Volumes/coveydata-1/APOGEE_Spectra/APOGEE2_DR13/allStar-apogee2-l30d.1.fits')
# Out:
# Filename: /Volumes/coveydata-1/APOGEE_Spectra/APOGEE2_DR13/allStar-apogee2-l30d.1.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      15   ()
#   1              BinTableHDU    408   50914R x 192C   [45A, 23A, 54A, 38A, 18A, 8A, I, 10A, E, E, E, E, E, E, D, D, D, D, J, J, J, 112A, J, I, E, J, 87A, J, 44A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 2E, 2E, 2E, 2E, E, E, E, 5A, 4A, 14A, I, 9E, 9E, 81E, 81E, 26E, 26E, 26E, 26E, E, E, E, E, E, E, E, E, E, 5A, J, 156A, 9J, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, 26E, 26J, 18A, 5A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 9A, E, E, I, I, E, E, 17A, 551A, 551A, 50J, 50J, 207E, 207E]
#   2              ImageHDU         6   (360,)   int32
# ...

# %%
data['Primary'].header
# Out:
# SIMPLE  =                    T / Written by IDL:  Tue Dec 22 14:14:47 2015
# BITPIX  =                   16 / Number of bits per data pixel
# NAXIS   =                    0 / Number of data axes
# EXTEND  =                    T / FITS data may contain extensions
# DATE    = '2015-12-22'         / Creation UTC (CCCC-MM-DD) date of FITS header
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode 2001A&A...376..359H
# HISTORY APRED VERSION: apogee2
# HISTORY APSTAR VERSION: stars
# HISTORY ASPCAP VERSION: l30d
# HISTORY RESULTS VERSION: apogee2-l30d.1
# HISTORY APRED SOFTWARE VERSION: v3_25
# HISTORY IDLWRAP SOFTWARE VERSION: v40
# HISTORY SPECLIB SOFTWARE VERSION: v16
# HISTORY DATE: Tue Dec 22 14:14:48 2015

# %%
HDU = data[0].header
HDU
# Out:
# SIMPLE  =                    T / Written by IDL:  Tue Dec 22 14:14:47 2015
# BITPIX  =                   16 / Number of bits per data pixel
# NAXIS   =                    0 / Number of data axes
# EXTEND  =                    T / FITS data may contain extensions
# DATE    = '2015-12-22'         / Creation UTC (CCCC-MM-DD) date of FITS header
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode 2001A&A...376..359H
# HISTORY APRED VERSION: apogee2
# HISTORY APSTAR VERSION: stars
# HISTORY ASPCAP VERSION: l30d
# HISTORY RESULTS VERSION: apogee2-l30d.1
# HISTORY APRED SOFTWARE VERSION: v3_25
# HISTORY IDLWRAP SOFTWARE VERSION: v40
# HISTORY SPECLIB SOFTWARE VERSION: v16
# HISTORY DATE: Tue Dec 22 14:14:48 2015

# %% [markdown]
# ### Opening allStar File

# %%
allStar = fits.open('/Volumes/coveydata-1/APOGEE_Spectra/APOGEE2_DR13/allStar-l30e.2.fits')

# %%
allStar.info()
# Out:
# Filename: /Volumes/coveydata-1/APOGEE_Spectra/APOGEE2_DR13/allStar-l30e.2.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      15   ()
#   1              BinTableHDU    417   164562R x 197C   [45A, 34A, 46A, 34A, 18A, 8A, I, 16A, E, E, E, E, E, E, D, D, D, D, J, J, J, 101A, J, I, E, J, 117A, J, 59A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 2E, 2E, 2E, 2E, E, E, E, 5A, 4A, 6A, I, E, E, E, 9E, 9E, 81E, 81E, E, E, E, E, E, E, E, E, E, E, E, E, 5A, J, 160A, 9J, 26E, 26E, 26E, 26E, 26E, 26E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, J, 26E, 26J, 18A, 12A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 17A, E, E, I, I, E, E, 20A, 737A, 665A, 50J, 50J, 207E, 23E]
#   2              ImageHDU         6   (360,)   int32
# ...

# %%
allStar[1].header
# Out:
# XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.11
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =                 5693 /Number of bytes per row
# NAXIS2  =               164562 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                  197 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'APSTAR_ID'          /
# TTYPE2  = 'TARGET_ID'          /
# TTYPE3  = 'ASPCAP_ID'          /
# TTYPE4  = 'FILE    '           /
# TTYPE5  = 'APOGEE_ID'          /
# TTYPE6  = 'TELESCOPE'          /
# TTYPE7  = 'LOCATION_ID'        /
# TTYPE8  = 'FIELD   '           /
# TTYPE9  = 'J       '           /
# TTYPE10 = 'J_ERR   '           /
# TTYPE11 = 'H       '           /
# TTYPE12 = 'H_ERR   '           /
# ...

# %%
allStar[1].header['TTYPE19']
# Out:
# 'APOGEE_TARGET1'

# %%
cols = allStar[1].columns
cols
# Out:
# ColDefs(
#     name = 'APSTAR_ID'; format = '45A'
#     name = 'TARGET_ID'; format = '34A'
#     name = 'ASPCAP_ID'; format = '46A'
#     name = 'FILE'; format = '34A'
#     name = 'APOGEE_ID'; format = '18A'
#     name = 'TELESCOPE'; format = '8A'
#     name = 'LOCATION_ID'; format = 'I'
#     name = 'FIELD'; format = '16A'
#     name = 'J'; format = 'E'
#     name = 'J_ERR'; format = 'E'
#     name = 'H'; format = 'E'
#     name = 'H_ERR'; format = 'E'
#     name = 'K'; format = 'E'
#     name = 'K_ERR'; format = 'E'
#     name = 'RA'; format = 'D'
#     name = 'DEC'; format = 'D'
#     name = 'GLON'; format = 'D'
#     name = 'GLAT'; format = 'D'
#     name = 'APOGEE_TARGET1'; format = 'J'
#     name = 'APOGEE_TARGET2'; format = 'J'
#     name = 'APOGEE_TARGET3'; format = 'J'
#     name = 'TARGFLAGS'; format = '101A'
#     name = 'NVISITS'; format = 'J'
#     name = 'COMMISS'; format = 'I'
#     name = 'SNR'; format = 'E'
#     name = 'STARFLAG'; format = 'J'
# ...
